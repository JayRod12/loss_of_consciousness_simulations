# %%
# %load_ext autoreload
# %autoreload 2
from brian2 import *
import experiment_9_single_module as ex_9

# %%
data = ex_9.run_simulation(15, 3, 0.4, 0.1)
# Out:
# Setting up synapses...
# 	EX_EX_SYN (595 synapses): 0.0176298618317s
# 	EX_IN_SYN (40 synapses): 0.0179660320282s
# 	IN_EX_SYN (400 synapses): 0.0189380645752s
# 	IN_IN_SYN (7 synapses): 0.0161499977112s
# Done [0.0938129425049 seconds]
# Running sym... Done [6.02275705338 seconds]
# Processing data and plotting...
# Done [0.434788942337 seconds]

# %%
x, y, xin, yin, mv = data

# %%
plt.plot(x, y, '.')
plt.show()

# %%
M = data[2]
t, v = M.t/ms, M.v[0]
mask = np.logical_and(t > 1000, t < 1050)
t = t[mask]
v = v[mask]
plt.plot(t, v)
plt.show()
# Out:
# --------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-64-9506705712bb> in <module>()
#       1 M = data[2]
# ----> 2 t, v = M.t/ms, M.v[0]
#       3 mask = np.logical_and(t > 1000, t < 1050)
#       4 t = t[mask]
#       5 v = v[mask]
#
# AttributeError: 'numpy.ndarray' object has no attribute 't'

# %%
X, Y = data[:2]

# %%
X
# Out:
# array([ 1002.4,  1002.4,  1002.4, ...,  1497.1,  1497.2,  1497.2])

# %%
mask = np.logical_and(X >= 1000, X < 1100)
plt.plot(X[mask], Y[mask], '.')
plt.show()
